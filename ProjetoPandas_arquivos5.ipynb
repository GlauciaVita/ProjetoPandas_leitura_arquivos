# %% [markdown]
# **Trabalhando com diferentes formatos de aquivos**

# %% [markdown]
# **Arquivo xml**

# %%
import pandas as pd

# %%
dados_imdb = pd.read_xml('/content/imdb_top_1000.xml')
dados_imdb.head()
# Out:
#    index                                        Poster_Link  \
# 0      0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1      1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2      2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3      3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4      4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# ...

# %%
dados_imdb.to_xml('dados_imdb.xml')

# %%
pd.read_xml('dados_imdb.xml')
# Out:
#      level_0  index                                        Poster_Link  \
# 0          0      0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1          1      1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2          2      2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3          3      3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4          4      4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..       ...    ...                                                ...
# 995      995    995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996      996    996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997      997    997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998      998    998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999      999    999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# ...

# %%
dados_imdb.groupby('Released_Year')['Meta_score'].mean().tail()
# Out:
# Released_Year
# 2017    79.473684
# 2018    77.692308
# 2019    76.904762
# 2020    82.750000
# PG      77.000000
# Name: Meta_score, dtype: float64

# %%
dados_imdb.query('Released_Year < 2015' and 'Meta_score > 80.0').head(10)
# Out:
#     index                                        Poster_Link  \
# 1       1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2       2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3       3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4       4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
# 5       5  https://m.media-amazon.com/images/M/MV5BNzA5ZD...
# 6       6  https://m.media-amazon.com/images/M/MV5BNGNhMD...
# 7       7  https://m.media-amazon.com/images/M/MV5BNDE4OT...
# 10     10  https://m.media-amazon.com/images/M/MV5BN2EyZj...
# 11     11  https://m.media-amazon.com/images/M/MV5BNWIwOD...
# 12     12  https://m.media-amazon.com/images/M/MV5BOTQ5ND...
#
#                                          Series_Title Released_Year  \
# 1                                       The Godfather          1972
# 2                                     The Dark Knight          2008
# 3                              The Godfather: Part II          1974
# ...

# %%
dados_rank = dados_imdb.groupby('Released_Year')[['Meta_score']].mean().tail(15)

dados_rank.plot(kind='barh', figsize=(10,6), color = 'green');
